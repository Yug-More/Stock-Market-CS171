# %% [markdown]
# # CS 171 Final Project – Data Pre-processing (NASDAQ-100)
#
# In this notebook, I prepare the NASDAQ-100 index data for my final project in CS 171.
#
# My goal in this project is to predict whether the NASDAQ-100 index will go **up or down on the next trading day** using historical price-based features. In this notebook, I:
#
# 1. Download daily historical data for the NASDAQ-100 index using `yfinance`.
# 2. Explore and clean the raw data.
# 3. Engineer features such as returns, moving averages, volatility, and momentum indicators.
# 4. Create a binary target label indicating whether the next day's close is higher than today's.
# 5. Split the data into **train**, **validation**, and **test** sets based on time.
#
# This notebook focuses purely on **data collection and pre-processing**. I will build and train the machine learning models in a separate **Model Construction** notebook.
